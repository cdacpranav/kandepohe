# %% [markdown]
# ### Importing Required Libraries

# %%
# Standard libraries for file handling and numerical operations
import os      
import random    
import numpy as np 
import pandas as pd  

# To Displays progress bars for loops
from tqdm import tqdm 

# Audio processing libraries
import librosa
import librosa.display  

# Visualization libraries
import seaborn as sns  
import matplotlib.pyplot as plt  

# To evaluate model performance using a confusion matrix
from sklearn.metrics import confusion_matrix  

# Preprocessing utilities
from sklearn.model_selection import train_test_split 
# Converts categorical labels to numerical labels 
from sklearn.preprocessing import LabelEncoder  
# Normalizes features to improve model performance
from sklearn.preprocessing import StandardScaler  

# Deep learning model training using TensorFlow Keras
from tensorflow.keras.models import Sequential  
from tensorflow.keras.layers import Dense, Dropout  
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten  

# Model evaluation utilities
from tensorflow.keras import models as tf_models  
from sklearn.metrics import classification_report

# %%
import os
import librosa
import numpy as np
import pandas as pd
import librosa.display
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import confusion_matrix, classification_report

# %% [markdown]
# ### Define Dataset Path

# %%
dataset_root = r"I:\My Drive"
dataset_subfolders = ["Audio_Speech_Actors_01-24", "Audio_Song_Actors_01-24"]

# %% [markdown]
# ### Define emotions based on RAVDESS Dataset

# %%
emotion_map = {'01': 'neutral', '02': 'calm', '03': 'happy', '04': 'sad',
               '05': 'angry', '06': 'fearful', '07': 'disgust', '08': 'surprised'}

# %% [markdown]
# ### Ensuring dataset_features directory exists

# %%
output_dir = r"I:\My Drive\SpeechEmotionDetection\dataset_features"
os.makedirs(output_dir, exist_ok=True)

# %% [markdown]
# ### Feature Extraction
# ### Audio Feature Extraction
# This function extracts three key features from an audio file:
# 1. **MFCCs (Mel-Frequency Cepstral Coefficients)**
#     - Captures timbral characteristics of speech.
#     - Timbre refers to the quality or color of a sound that makes it distinct from other sounds, even when they have the same pitch and loudness.
# 2. **Chroma Features**
#     - Represents pitch class distribution in the audio.
# 3. **Mel Spectrogram**
#     - Shows energy distribution over different frequencies.
#
# These features are essential for training a machine learning model to classify speech emotions.

# %%
def extract_features(file_path):
    """
    Extracts audio features (MFCCs, Chroma, and Mel Spectrogram) from a given audio file.
    And returns a feature vector (numpy array) containing MFCCs, Chroma, and Mel Spectrogram.
    """
    y, sr = librosa.load(file_path, sr=None)

    # Extract MFCCs
    mfccs = np.mean(librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40).T, axis=0)

    # Extract Chroma
    chroma = np.mean(librosa.feature.chroma_stft(y=y, sr=sr).T, axis=0)

    # Extract Mel Spectrogram
    mel = np.mean(librosa.feature.melspectrogram(y=y, sr=sr).T, axis=0)

    return np.hstack([mfccs, chroma, mel])

# %% [markdown]
# ### Dataseet Processing

# %%
# Function to process a dataset folder
def process_dataset(dataset_path, category, data):
    """Processes audio files from a dataset directory, extracts features and stores them in strucuted list"""
    # List to store all file paths and names
    all_files = []
    # Iterate through each actor's folder inside the dataset directory
    for actor_folder in os.listdir(dataset_path):
        actor_path = os.path.join(dataset_path, actor_folder)
        if not os.path.isdir(actor_path):
            continue

        # Iterate through audio files inside each actor's folder
        for file_name in os.listdir(actor_path):
            file_path = os.path.join(actor_path, file_name)

            # Ignore non-audio files (only process .wav files)
            if not file_name.lower().endswith(".wav"):
                continue  # Skip non-audio files

            all_files.append((file_path, file_name))


    # Display processing of files found in the category
    print(f"Processing {category}: {len(all_files)} files")

    # Process each audio file and extract features
    for file_path, file_name in tqdm(all_files, desc=f"{category}"):
        try:
            features = extract_features(file_path)
            emotion_code = file_name.split("-")[2]
            emotion = emotion_map.get(emotion_code, "unknown")
            data.append([file_path, category, emotion] + features.tolist())
        except Exception as e:
            print(f"Error processing {file_name}: {e}")

# %%
# Initializing empty list to store extracted features
data = []

# Iterate through each subfolder in the dataset
for subfolder in dataset_subfolders:
    process_dataset(os.path.join(dataset_root, subfolder), subfolder, data)

# Check if feature extraction was successful
if data:
    # Define Dataframe to store metadata and extracted features
    columns = ["file_path", "category", "emotion"] + [f"feature_{i}" for i in range(len(data[0]) - 3)]
    df = pd.DataFrame(data, columns=columns)

    #Converting Dataframe to csv
    df.to_csv(os.path.join(output_dir, "audio_features.csv"), index=False)
    print("Feature extraction completed! Data saved to dataset_features/audio_features.csv")
else:
    print("No valid audio files found for feature extraction.")
# Out:
# Processing Audio_Speech_Actors_01-24: 1440 files
# Audio_Speech_Actors_01-24: 100%|██████████| 1440/1440 [01:20<00:00, 17.79it/s]
# Processing Audio_Song_Actors_01-24: 1012 files
# Audio_Song_Actors_01-24: 100%|██████████| 1012/1012 [01:05<00:00, 15.44it/s]
# Feature extraction completed! Data saved to dataset_features/audio_features.csv

# %%
# Load the saved CSV file for verification
df = pd.read_csv(r"I:\My Drive\SpeechEmotionDetection\dataset_features\audio_features.csv")

# Display Top 5 rows
df.head()
# Out:
#                                            file_path  \
# 0  I:\My Drive\Audio_Speech_Actors_01-24\Actor_09...
# 1  I:\My Drive\Audio_Speech_Actors_01-24\Actor_09...
# 2  I:\My Drive\Audio_Speech_Actors_01-24\Actor_09...
# 3  I:\My Drive\Audio_Speech_Actors_01-24\Actor_09...
# 4  I:\My Drive\Audio_Speech_Actors_01-24\Actor_09...
#
#                     category  emotion   feature_0   feature_1  feature_2  \
# 0  Audio_Speech_Actors_01-24  disgust -683.979553   89.553009   1.002610
# 1  Audio_Speech_Actors_01-24  fearful -590.847839   63.929508  -0.203056
# 2  Audio_Speech_Actors_01-24     calm -792.877991   84.402924  11.711248
# 3  Audio_Speech_Actors_01-24  fearful -625.412415   89.345726   2.360502
# 4  Audio_Speech_Actors_01-24      sad -749.033630  101.306038   5.393279
#
#    feature_3  feature_4  feature_5  feature_6  ...   feature_170  \
# 0  12.814185  13.847642  15.458847  -5.636692  ...  1.838574e-07
# 1  12.907093   5.051848  15.743986  -7.324590  ...  1.114628e-06
# 2  22.659185  10.396310  20.110916   3.031713  ...  1.451464e-08
# 3  14.402076  15.371239  23.466177  -5.400414  ...  4.581117e-07
# 4  22.513130  12.124167  22.545036   1.623664  ...  2.016923e-08
#
#     feature_171   feature_172   feature_173   feature_174   feature_175  \
# 0  1.757045e-07  1.475160e-07  9.414156e-08  8.740297e-08  8.861492e-08
# 1  8.043079e-07  7.851357e-07  5.055985e-07  4.639778e-07  4.841817e-07
# 2  9.801979e-09  6.760149e-09  5.788878e-09  5.774577e-09  5.857522e-09
# 3  4.393920e-07  3.803131e-07  2.345599e-07  1.345453e-07  1.192339e-07
# 4  1.952276e-08  1.379919e-08  1.239733e-08  1.305881e-08  1.108244e-08
#
#     feature_176   feature_177   feature_178   feature_179
# 0  6.243140e-08  2.445380e-08  7.480933e-09  7.090482e-09
# 1  3.481075e-07  1.276913e-07  1.381547e-08  7.907723e-09
# 2  5.546776e-09  5.300761e-09  5.366086e-09  5.390684e-09
# 3  8.506431e-08  4.392666e-08  1.047715e-08  8.753392e-09
# 4  8.529398e-09  8.023850e-09  6.985719e-09  6.711362e-09
#
# [5 rows x 183 columns]

# %% [markdown]
# ### Plotting Sample Waveform and MFCC

# %%
# Randomly select audio file from dataset
audio_file = random.choice(df['file_path'])

# Load audio file
y, sr = librosa.load(audio_file, sr=None)

# Compute MFCCs
mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40)

# Create a figure with subplots
fig, ax = plt.subplots(nrows=2, figsize=(10, 6))

# Plot waveform
ax[0].set_title(f"Waveform of {audio_file.split('/')[-1]}")
librosa.display.waveshow(y, sr=sr, ax=ax[0])
ax[0].set_xlabel("Time")
ax[0].set_ylabel("Amplitude")

# Plot MFCC features
img = librosa.display.specshow(mfccs, x_axis="time", sr=sr, ax=ax[1], cmap="viridis")
ax[1].set_title("MFCC Features")
ax[1].set_xlabel("Time")
ax[1].set_ylabel("MFCC Coefficients")
fig.colorbar(img, ax=ax[1], format="%+2.f")
# Show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Preprocessing Dataset

# %%
# Encoding emotions
print(df['emotion'])
label_encoder = LabelEncoder()
df["emotion"] = label_encoder.fit_transform(df["emotion"])
df['emotion']
# Out:
# 0       disgust
# 1       fearful
# 2          calm
# 3       fearful
# 4           sad
#          ...
# 2447      angry
# 2448       calm
# 2449    fearful
# 2450      angry
# 2451      happy
# Name: emotion, Length: 2452, dtype: object
# 0       2
# 1       3
# 2       1
# 3       3
# 4       6
#        ..
# 2447    0
# 2448    1
# 2449    3
# 2450    0
# 2451    4
# Name: emotion, Length: 2452, dtype: int64

# %%
# Defining columns to exclude non-feature columns
exclude_columns = ["emotion", "file_path", "category"]

# %%
# Split data into features and labels
X = df.drop(columns=exclude_columns, axis=1)
y = df["emotion"]

# %%
# Standardize features
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
# Split into training and testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=28)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((1716, 180), (736, 180), (1716,), (736,))

# %% [markdown]
# #### What is **.npy**?
# * NumPy Binary Format is a file format used by NumPy to store arrays efficiently.
# * *It saves arrays in binary format that retains their structure and datatype

# %%
# Saving preprocessed feature arrays and labels as .npy files for quick loading

np.save(os.path.join(output_dir, "X_train.npy"), X_train)

np.save(os.path.join(output_dir, "X_test.npy"), X_test)

np.save(os.path.join(output_dir, "y_train.npy"), y_train)

np.save(os.path.join(output_dir, "y_test.npy"), y_test)

print("Data preprocessing completed! Datasets saved in dataset_features/")
# Out:
# Data preprocessing completed! Datasets saved in dataset_features/

# %% [markdown]
# ### Model Training

# %%
# Load dataset
dataset_dir = r"I:\My Drive\SpeechEmotionDetection\dataset_features"
X_train = np.load(os.path.join(dataset_dir, "X_train.npy"))
X_test = np.load(os.path.join(dataset_dir, "X_test.npy"))
y_train = np.load(os.path.join(dataset_dir, "y_train.npy"))
y_test = np.load(os.path.join(dataset_dir, "y_test.npy"))

# %% [markdown]
# ### Defining CNN Model
# - This model uses **1D convolutional layers** to extract meaningful features from **audio input sequences**.
# - Using **Sequential layer** as it is a linear stack of layers in Keras, used to build neural network models where each layer has exactly one input tensor and one output tensor. It is simple to use but only supports layer-by-layer stacking.
# - **Pooling layers** reduce dimensions and prevent overfitting.
# - The **Dense layer and Dropout** enhance learning, followed by **Softmax** for final classification.
# - The final layer has neurons equal to the **number of unique emotions** in the dataset.

# %%
# Define CNN Model
model = Sequential([
    # Input Layer: Extracts local features from the input sequence
    Conv1D(64, kernel_size=3, activation="relu", input_shape=(X_train.shape[1], 1)),
    # Further reduces size and prevents overfitting
    MaxPooling1D(2),
    # Learns more complex feature representations
    Conv1D(128, kernel_size=3, activation="relu"),
    # Further reduces size and prevents overfitting
    MaxPooling1D(2),
    # Converts the extracted feature maps into a 1D vector for Dense layers
    Flatten(),
    Dense(256, activation="relu"),
    # To Prevents overfitting by randomly deactivating neurons during training
    Dropout(0.5),
    # Output Layer: Softmax activation for multi-class emotion classification
    Dense(len(np.unique(y_train)), activation="softmax")
])
# Out:
# C:\Users\EL-Dorado\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Compiling the Model
model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_8 (Conv1D)               │ (None, 178, 64)        │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_8 (MaxPooling1D)  │ (None, 89, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_9 (Conv1D)               │ (None, 87, 128)        │        24,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_9 (MaxPooling1D)  │ (None, 43, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_4 (Flatten)             │ (None, 5504)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 256)            │     1,409,280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 8)              │         2,056 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,436,296 (5.48 MB)
#  Trainable params: 1,436,296 (5.48 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the Model
history = model.fit(X_train, y_train, epochs=500, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.2332 - loss: 1.9193 - val_accuracy: 0.3655 - val_loss: 1.5989
# Epoch 2/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.4068 - loss: 1.5729 - val_accuracy: 0.4918 - val_loss: 1.3833
# Epoch 3/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.5390 - loss: 1.2798 - val_accuracy: 0.5041 - val_loss: 1.3427
# Epoch 4/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.5740 - loss: 1.2028 - val_accuracy: 0.5543 - val_loss: 1.2589
# Epoch 5/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.6159 - loss: 1.0757 - val_accuracy: 0.5815 - val_loss: 1.1531
# Epoch 6/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.6574 - loss: 0.9447 - val_accuracy: 0.5924 - val_loss: 1.1317
# Epoch 7/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7147 - loss: 0.8396 - val_accuracy: 0.6168 - val_loss: 1.0738
# Epoch 8/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.7331 - loss: 0.7991 - val_accuracy: 0.5829 - val_loss: 1.1744
# Epoch 9/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.7325 - loss: 0.7330 - val_accuracy: 0.6304 - val_loss: 1.0555
# Epoch 10/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.7650 - loss: 0.6542 - val_accuracy: 0.6467 - val_loss: 1.0162
# Epoch 11/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.7969 - loss: 0.5793 - val_accuracy: 0.6332 - val_loss: 1.0141
# Epoch 12/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.8164 - loss: 0.5339 - val_accuracy: 0.6630 - val_loss: 0.9691
# Epoch 13/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8282 - loss: 0.4976 - val_accuracy: 0.6576 - val_loss: 1.0584
# Epoch 14/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.8318 - loss: 0.4898 - val_accuracy: 0.6617 - val_loss: 1.0040
# Epoch 15/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.8533 - loss: 0.4136 - val_accuracy: 0.6739 - val_loss: 1.0000
# Epoch 16/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8712 - loss: 0.3808 - val_accuracy: 0.6821 - val_loss: 1.0034
# Epoch 17/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8719 - loss: 0.3487 - val_accuracy: 0.6753 - val_loss: 1.0724
# Epoch 18/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8972 - loss: 0.3237 - val_accuracy: 0.6780 - val_loss: 1.0015
# Epoch 19/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9131 - loss: 0.2722 - val_accuracy: 0.7011 - val_loss: 1.0308
# Epoch 20/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9180 - loss: 0.2133 - val_accuracy: 0.7011 - val_loss: 0.9938
# Epoch 21/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9277 - loss: 0.2137 - val_accuracy: 0.7065 - val_loss: 1.0044
# Epoch 22/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9225 - loss: 0.2200 - val_accuracy: 0.6943 - val_loss: 1.0850
# Epoch 23/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9445 - loss: 0.1672 - val_accuracy: 0.6997 - val_loss: 1.0567
# Epoch 24/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9200 - loss: 0.2265 - val_accuracy: 0.6902 - val_loss: 1.1185
# Epoch 25/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9516 - loss: 0.1602 - val_accuracy: 0.7065 - val_loss: 1.0719
# Epoch 26/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9412 - loss: 0.1717 - val_accuracy: 0.6970 - val_loss: 1.1258
# Epoch 27/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9500 - loss: 0.1338 - val_accuracy: 0.7092 - val_loss: 1.1501
# Epoch 28/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9646 - loss: 0.1146 - val_accuracy: 0.7079 - val_loss: 1.2103
# Epoch 29/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9590 - loss: 0.1464 - val_accuracy: 0.7310 - val_loss: 1.0747
# Epoch 30/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9702 - loss: 0.1209 - val_accuracy: 0.7283 - val_loss: 1.0984
# Epoch 31/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9632 - loss: 0.1204 - val_accuracy: 0.7147 - val_loss: 1.1719
# Epoch 32/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9726 - loss: 0.1004 - val_accuracy: 0.7269 - val_loss: 1.1090
# Epoch 33/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9771 - loss: 0.0953 - val_accuracy: 0.7228 - val_loss: 1.2059
# Epoch 34/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9518 - loss: 0.1395 - val_accuracy: 0.7255 - val_loss: 1.1553
# Epoch 35/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9804 - loss: 0.0783 - val_accuracy: 0.7106 - val_loss: 1.3869
# Epoch 36/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9799 - loss: 0.0703 - val_accuracy: 0.7160 - val_loss: 1.1933
# Epoch 37/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9836 - loss: 0.0687 - val_accuracy: 0.7323 - val_loss: 1.1348
# Epoch 38/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9795 - loss: 0.0686 - val_accuracy: 0.7378 - val_loss: 1.1920
# Epoch 39/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9831 - loss: 0.0673 - val_accuracy: 0.7038 - val_loss: 1.2559
# Epoch 40/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9812 - loss: 0.0709 - val_accuracy: 0.7079 - val_loss: 1.3787
# Epoch 41/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9768 - loss: 0.0646 - val_accuracy: 0.7201 - val_loss: 1.3246
# Epoch 42/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9821 - loss: 0.0713 - val_accuracy: 0.7092 - val_loss: 1.6029
# Epoch 43/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9569 - loss: 0.1338 - val_accuracy: 0.7201 - val_loss: 1.3071
# Epoch 44/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9716 - loss: 0.0918 - val_accuracy: 0.7092 - val_loss: 1.2805
# Epoch 45/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9683 - loss: 0.0924 - val_accuracy: 0.7242 - val_loss: 1.2919
# Epoch 46/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9831 - loss: 0.0667 - val_accuracy: 0.7228 - val_loss: 1.3146
# Epoch 47/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9819 - loss: 0.0655 - val_accuracy: 0.7120 - val_loss: 1.4550
# Epoch 48/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9835 - loss: 0.0561 - val_accuracy: 0.7201 - val_loss: 1.3932
# Epoch 49/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9755 - loss: 0.0594 - val_accuracy: 0.7188 - val_loss: 1.4256
# Epoch 50/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9796 - loss: 0.0632 - val_accuracy: 0.7323 - val_loss: 1.3215
# Epoch 51/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9800 - loss: 0.0620 - val_accuracy: 0.7255 - val_loss: 1.3826
# Epoch 52/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9772 - loss: 0.0611 - val_accuracy: 0.7242 - val_loss: 1.4022
# Epoch 53/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9801 - loss: 0.0706 - val_accuracy: 0.7310 - val_loss: 1.4520
# Epoch 54/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9861 - loss: 0.0541 - val_accuracy: 0.7337 - val_loss: 1.4038
# Epoch 55/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9857 - loss: 0.0536 - val_accuracy: 0.7255 - val_loss: 1.5090
# Epoch 56/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9741 - loss: 0.0771 - val_accuracy: 0.7337 - val_loss: 1.4942
# Epoch 57/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9874 - loss: 0.0363 - val_accuracy: 0.7351 - val_loss: 1.4504
# Epoch 58/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9929 - loss: 0.0370 - val_accuracy: 0.7310 - val_loss: 1.4546
# Epoch 59/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9901 - loss: 0.0334 - val_accuracy: 0.7269 - val_loss: 1.4921
# Epoch 60/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9907 - loss: 0.0290 - val_accuracy: 0.7337 - val_loss: 1.5092
# Epoch 61/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9857 - loss: 0.0497 - val_accuracy: 0.7391 - val_loss: 1.3853
# Epoch 62/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9802 - loss: 0.0625 - val_accuracy: 0.7269 - val_loss: 1.3814
# Epoch 63/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9893 - loss: 0.0364 - val_accuracy: 0.7337 - val_loss: 1.4924
# Epoch 64/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9855 - loss: 0.0468 - val_accuracy: 0.7378 - val_loss: 1.3951
# Epoch 65/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9892 - loss: 0.0361 - val_accuracy: 0.7323 - val_loss: 1.4542
# Epoch 66/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9777 - loss: 0.0592 - val_accuracy: 0.7188 - val_loss: 1.4920
# Epoch 67/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9778 - loss: 0.0565 - val_accuracy: 0.7405 - val_loss: 1.3335
# Epoch 68/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9845 - loss: 0.0395 - val_accuracy: 0.7310 - val_loss: 1.4588
# Epoch 69/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9811 - loss: 0.0452 - val_accuracy: 0.7405 - val_loss: 1.5464
# Epoch 70/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9845 - loss: 0.0446 - val_accuracy: 0.7269 - val_loss: 1.4937
# Epoch 71/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9917 - loss: 0.0323 - val_accuracy: 0.7405 - val_loss: 1.4996
# Epoch 72/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9920 - loss: 0.0289 - val_accuracy: 0.7269 - val_loss: 1.7884
# Epoch 73/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9808 - loss: 0.0522 - val_accuracy: 0.7351 - val_loss: 1.6379
# Epoch 74/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9798 - loss: 0.0699 - val_accuracy: 0.7351 - val_loss: 1.6369
# Epoch 75/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9809 - loss: 0.0644 - val_accuracy: 0.7133 - val_loss: 1.5835
# Epoch 76/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9777 - loss: 0.0867 - val_accuracy: 0.7378 - val_loss: 1.4497
# Epoch 77/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9811 - loss: 0.0592 - val_accuracy: 0.7351 - val_loss: 1.5073
# Epoch 78/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9919 - loss: 0.0469 - val_accuracy: 0.7269 - val_loss: 1.4846
# Epoch 79/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9927 - loss: 0.0249 - val_accuracy: 0.7337 - val_loss: 1.6205
# Epoch 80/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9956 - loss: 0.0244 - val_accuracy: 0.7405 - val_loss: 1.5527
# Epoch 81/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9919 - loss: 0.0258 - val_accuracy: 0.7351 - val_loss: 1.6848
# Epoch 82/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9833 - loss: 0.0415 - val_accuracy: 0.7323 - val_loss: 1.6478
# Epoch 83/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9861 - loss: 0.0500 - val_accuracy: 0.7391 - val_loss: 1.5124
# Epoch 84/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9916 - loss: 0.0287 - val_accuracy: 0.7473 - val_loss: 1.5151
# Epoch 85/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9902 - loss: 0.0347 - val_accuracy: 0.7255 - val_loss: 1.6658
# Epoch 86/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9882 - loss: 0.0379 - val_accuracy: 0.7378 - val_loss: 1.5656
# Epoch 87/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9859 - loss: 0.0471 - val_accuracy: 0.7255 - val_loss: 1.6471
# Epoch 88/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9859 - loss: 0.0408 - val_accuracy: 0.7351 - val_loss: 1.6161
# Epoch 89/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9827 - loss: 0.0659 - val_accuracy: 0.7269 - val_loss: 1.5727
# Epoch 90/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9913 - loss: 0.0325 - val_accuracy: 0.7364 - val_loss: 1.5717
# Epoch 91/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9749 - loss: 0.0561 - val_accuracy: 0.7364 - val_loss: 1.5958
# Epoch 92/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9892 - loss: 0.0362 - val_accuracy: 0.7405 - val_loss: 1.4747
# Epoch 93/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9890 - loss: 0.0340 - val_accuracy: 0.7378 - val_loss: 1.5418
# Epoch 94/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9921 - loss: 0.0272 - val_accuracy: 0.7459 - val_loss: 1.4739
# Epoch 95/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9810 - loss: 0.0537 - val_accuracy: 0.7432 - val_loss: 1.5841
# Epoch 96/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9898 - loss: 0.0494 - val_accuracy: 0.7405 - val_loss: 1.6158
# Epoch 97/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9803 - loss: 0.0514 - val_accuracy: 0.7364 - val_loss: 1.5818
# Epoch 98/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9920 - loss: 0.0301 - val_accuracy: 0.7160 - val_loss: 1.6705
# Epoch 99/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9866 - loss: 0.0552 - val_accuracy: 0.7391 - val_loss: 1.5687
# Epoch 100/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9897 - loss: 0.0435 - val_accuracy: 0.7514 - val_loss: 1.5074
# Epoch 101/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9964 - loss: 0.0181 - val_accuracy: 0.7405 - val_loss: 1.6894
# Epoch 102/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9923 - loss: 0.0265 - val_accuracy: 0.7418 - val_loss: 1.6934
# Epoch 103/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9958 - loss: 0.0136 - val_accuracy: 0.7473 - val_loss: 1.6557
# Epoch 104/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9956 - loss: 0.0155 - val_accuracy: 0.7582 - val_loss: 1.7071
# Epoch 105/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9905 - loss: 0.0228 - val_accuracy: 0.7473 - val_loss: 1.5882
# Epoch 106/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9970 - loss: 0.0167 - val_accuracy: 0.7418 - val_loss: 1.7311
# Epoch 107/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9895 - loss: 0.0291 - val_accuracy: 0.7432 - val_loss: 1.6491
# Epoch 108/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9912 - loss: 0.0573 - val_accuracy: 0.7418 - val_loss: 1.6391
# Epoch 109/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9933 - loss: 0.0207 - val_accuracy: 0.7283 - val_loss: 1.7905
# Epoch 110/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9891 - loss: 0.0339 - val_accuracy: 0.7418 - val_loss: 1.6006
# Epoch 111/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9965 - loss: 0.0146 - val_accuracy: 0.7296 - val_loss: 1.7411
# Epoch 112/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9913 - loss: 0.0284 - val_accuracy: 0.7351 - val_loss: 1.6734
# Epoch 113/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9937 - loss: 0.0296 - val_accuracy: 0.7310 - val_loss: 1.8275
# Epoch 114/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9958 - loss: 0.0183 - val_accuracy: 0.7337 - val_loss: 1.8232
# Epoch 115/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9921 - loss: 0.0259 - val_accuracy: 0.7364 - val_loss: 1.8260
# Epoch 116/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9915 - loss: 0.0316 - val_accuracy: 0.7459 - val_loss: 1.6732
# Epoch 117/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9889 - loss: 0.0397 - val_accuracy: 0.7215 - val_loss: 1.9451
# Epoch 118/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9869 - loss: 0.0559 - val_accuracy: 0.7188 - val_loss: 1.7894
# Epoch 119/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9938 - loss: 0.0262 - val_accuracy: 0.7541 - val_loss: 1.7192
# Epoch 120/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9961 - loss: 0.0212 - val_accuracy: 0.7269 - val_loss: 1.7695
# Epoch 121/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9835 - loss: 0.0376 - val_accuracy: 0.7283 - val_loss: 1.8496
# Epoch 122/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9933 - loss: 0.0266 - val_accuracy: 0.7432 - val_loss: 1.8761
# Epoch 123/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9872 - loss: 0.0337 - val_accuracy: 0.7649 - val_loss: 1.6892
# Epoch 124/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9957 - loss: 0.0170 - val_accuracy: 0.7609 - val_loss: 1.8597
# Epoch 125/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9885 - loss: 0.0245 - val_accuracy: 0.7486 - val_loss: 1.8997
# Epoch 126/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9900 - loss: 0.0428 - val_accuracy: 0.7405 - val_loss: 1.9051
# Epoch 127/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9838 - loss: 0.0700 - val_accuracy: 0.7446 - val_loss: 1.7471
# Epoch 128/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9805 - loss: 0.0517 - val_accuracy: 0.7364 - val_loss: 1.7691
# Epoch 129/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9853 - loss: 0.0513 - val_accuracy: 0.7418 - val_loss: 1.6567
# Epoch 130/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9902 - loss: 0.0321 - val_accuracy: 0.7283 - val_loss: 1.8933
# Epoch 131/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9906 - loss: 0.0305 - val_accuracy: 0.7215 - val_loss: 1.8750
# Epoch 132/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9949 - loss: 0.0308 - val_accuracy: 0.7486 - val_loss: 1.7427
# Epoch 133/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9849 - loss: 0.0324 - val_accuracy: 0.7310 - val_loss: 1.7767
# Epoch 134/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9907 - loss: 0.0326 - val_accuracy: 0.7269 - val_loss: 1.8268
# Epoch 135/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9952 - loss: 0.0186 - val_accuracy: 0.7500 - val_loss: 1.8628
# Epoch 136/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9969 - loss: 0.0132 - val_accuracy: 0.7432 - val_loss: 1.7983
# Epoch 137/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9872 - loss: 0.0340 - val_accuracy: 0.7541 - val_loss: 1.8727
# Epoch 138/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9894 - loss: 0.0366 - val_accuracy: 0.7459 - val_loss: 1.8341
# Epoch 139/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9946 - loss: 0.0199 - val_accuracy: 0.7418 - val_loss: 1.8686
# Epoch 140/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9961 - loss: 0.0194 - val_accuracy: 0.7541 - val_loss: 1.7767
# Epoch 141/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9920 - loss: 0.0177 - val_accuracy: 0.7405 - val_loss: 1.9214
# Epoch 142/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9933 - loss: 0.0249 - val_accuracy: 0.7527 - val_loss: 1.8826
# Epoch 143/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9940 - loss: 0.0176 - val_accuracy: 0.7405 - val_loss: 1.8299
# Epoch 144/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9973 - loss: 0.0123 - val_accuracy: 0.7432 - val_loss: 2.0824
# Epoch 145/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9960 - loss: 0.0173 - val_accuracy: 0.7323 - val_loss: 2.0921
# Epoch 146/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9916 - loss: 0.0175 - val_accuracy: 0.7486 - val_loss: 1.8884
# Epoch 147/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9991 - loss: 0.0088 - val_accuracy: 0.7446 - val_loss: 2.0288
# Epoch 148/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9957 - loss: 0.0162 - val_accuracy: 0.7527 - val_loss: 1.8990
# Epoch 149/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9908 - loss: 0.0297 - val_accuracy: 0.7541 - val_loss: 2.0510
# Epoch 150/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9968 - loss: 0.0145 - val_accuracy: 0.7500 - val_loss: 1.9849
# Epoch 151/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9938 - loss: 0.0185 - val_accuracy: 0.7351 - val_loss: 2.0267
# Epoch 152/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9953 - loss: 0.0129 - val_accuracy: 0.7405 - val_loss: 2.0280
# Epoch 153/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9963 - loss: 0.0112 - val_accuracy: 0.7554 - val_loss: 1.9527
# Epoch 154/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9949 - loss: 0.0149 - val_accuracy: 0.7432 - val_loss: 1.9681
# Epoch 155/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9981 - loss: 0.0122 - val_accuracy: 0.7364 - val_loss: 2.0584
# Epoch 156/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9946 - loss: 0.0191 - val_accuracy: 0.7337 - val_loss: 2.0050
# Epoch 157/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9926 - loss: 0.0214 - val_accuracy: 0.7554 - val_loss: 1.7904
# Epoch 158/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9940 - loss: 0.0165 - val_accuracy: 0.7391 - val_loss: 1.7906
# Epoch 159/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9987 - loss: 0.0106 - val_accuracy: 0.7500 - val_loss: 1.9325
# Epoch 160/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9935 - loss: 0.0255 - val_accuracy: 0.7446 - val_loss: 1.9275
# Epoch 161/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9915 - loss: 0.0157 - val_accuracy: 0.7296 - val_loss: 2.1385
# Epoch 162/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9929 - loss: 0.0312 - val_accuracy: 0.7364 - val_loss: 2.1526
# Epoch 163/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9945 - loss: 0.0264 - val_accuracy: 0.7174 - val_loss: 2.0428
# Epoch 164/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9895 - loss: 0.0243 - val_accuracy: 0.7527 - val_loss: 2.0158
# Epoch 165/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9930 - loss: 0.0206 - val_accuracy: 0.7296 - val_loss: 2.0128
# Epoch 166/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9947 - loss: 0.0204 - val_accuracy: 0.7486 - val_loss: 2.2011
# Epoch 167/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9932 - loss: 0.0159 - val_accuracy: 0.7405 - val_loss: 2.1162
# Epoch 168/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9924 - loss: 0.0220 - val_accuracy: 0.7473 - val_loss: 2.0949
# Epoch 169/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9942 - loss: 0.0214 - val_accuracy: 0.7432 - val_loss: 2.2204
# Epoch 170/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9873 - loss: 0.0396 - val_accuracy: 0.7201 - val_loss: 2.5503
# Epoch 171/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9804 - loss: 0.1097 - val_accuracy: 0.7106 - val_loss: 2.2280
# Epoch 172/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9772 - loss: 0.0713 - val_accuracy: 0.7351 - val_loss: 2.0943
# Epoch 173/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9846 - loss: 0.0431 - val_accuracy: 0.7269 - val_loss: 2.1419
# Epoch 174/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9918 - loss: 0.0295 - val_accuracy: 0.7255 - val_loss: 2.1375
# Epoch 175/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9945 - loss: 0.0236 - val_accuracy: 0.7323 - val_loss: 2.1874
# Epoch 176/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9946 - loss: 0.0191 - val_accuracy: 0.7337 - val_loss: 2.1352
# Epoch 177/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9949 - loss: 0.0215 - val_accuracy: 0.7527 - val_loss: 2.2285
# Epoch 178/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9946 - loss: 0.0166 - val_accuracy: 0.7323 - val_loss: 2.1663
# Epoch 179/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9941 - loss: 0.0165 - val_accuracy: 0.7364 - val_loss: 2.2487
# Epoch 180/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9926 - loss: 0.0202 - val_accuracy: 0.7514 - val_loss: 2.0202
# Epoch 181/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9960 - loss: 0.0145 - val_accuracy: 0.7351 - val_loss: 2.3644
# Epoch 182/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9923 - loss: 0.0431 - val_accuracy: 0.7228 - val_loss: 2.2617
# Epoch 183/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9818 - loss: 0.0434 - val_accuracy: 0.7296 - val_loss: 2.1130
# Epoch 184/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9938 - loss: 0.0206 - val_accuracy: 0.7391 - val_loss: 2.2464
# Epoch 185/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9864 - loss: 0.0376 - val_accuracy: 0.7446 - val_loss: 2.1482
# Epoch 186/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9936 - loss: 0.0150 - val_accuracy: 0.7364 - val_loss: 2.0941
# Epoch 187/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9950 - loss: 0.0217 - val_accuracy: 0.7255 - val_loss: 2.1936
# Epoch 188/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9912 - loss: 0.0167 - val_accuracy: 0.7351 - val_loss: 2.1627
# Epoch 189/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9908 - loss: 0.0249 - val_accuracy: 0.7323 - val_loss: 2.2748
# Epoch 190/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9938 - loss: 0.0156 - val_accuracy: 0.7473 - val_loss: 2.0498
# Epoch 191/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9922 - loss: 0.0471 - val_accuracy: 0.7432 - val_loss: 2.2073
# Epoch 192/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9955 - loss: 0.0409 - val_accuracy: 0.7514 - val_loss: 1.9469
# Epoch 193/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9948 - loss: 0.0134 - val_accuracy: 0.7432 - val_loss: 2.0608
# Epoch 194/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.9935 - loss: 0.0225 - val_accuracy: 0.7283 - val_loss: 2.1813
# Epoch 195/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9920 - loss: 0.0258 - val_accuracy: 0.7418 - val_loss: 2.4134
# Epoch 196/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9882 - loss: 0.0414 - val_accuracy: 0.7405 - val_loss: 2.1620
# Epoch 197/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9929 - loss: 0.0321 - val_accuracy: 0.7364 - val_loss: 2.0851
# Epoch 198/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9957 - loss: 0.0179 - val_accuracy: 0.7568 - val_loss: 2.1057
# Epoch 199/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9975 - loss: 0.0069 - val_accuracy: 0.7446 - val_loss: 2.2670
# Epoch 200/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9935 - loss: 0.0195 - val_accuracy: 0.7527 - val_loss: 2.1674
# Epoch 201/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9966 - loss: 0.0124 - val_accuracy: 0.7582 - val_loss: 2.0482
# Epoch 202/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9938 - loss: 0.0316 - val_accuracy: 0.7486 - val_loss: 2.1508
# Epoch 203/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9925 - loss: 0.0231 - val_accuracy: 0.7541 - val_loss: 1.9282
# Epoch 204/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9964 - loss: 0.0168 - val_accuracy: 0.7283 - val_loss: 2.2925
# Epoch 205/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9909 - loss: 0.0227 - val_accuracy: 0.7609 - val_loss: 2.1110
# Epoch 206/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9993 - loss: 0.0067 - val_accuracy: 0.7391 - val_loss: 2.1504
# Epoch 207/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9987 - loss: 0.0084 - val_accuracy: 0.7432 - val_loss: 2.2027
# Epoch 208/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9948 - loss: 0.0123 - val_accuracy: 0.7514 - val_loss: 2.1561
# Epoch 209/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9959 - loss: 0.0114 - val_accuracy: 0.7554 - val_loss: 2.1913
# Epoch 210/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9976 - loss: 0.0075 - val_accuracy: 0.7337 - val_loss: 2.2544
# Epoch 211/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9981 - loss: 0.0075 - val_accuracy: 0.7364 - val_loss: 2.4979
# Epoch 212/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9964 - loss: 0.0106 - val_accuracy: 0.7500 - val_loss: 2.2308
# Epoch 213/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9977 - loss: 0.0112 - val_accuracy: 0.7568 - val_loss: 2.1522
# Epoch 214/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9965 - loss: 0.0095 - val_accuracy: 0.7500 - val_loss: 2.2884
# Epoch 215/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9954 - loss: 0.0167 - val_accuracy: 0.7432 - val_loss: 2.2358
# Epoch 216/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9953 - loss: 0.0125 - val_accuracy: 0.7296 - val_loss: 2.1685
# Epoch 217/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9906 - loss: 0.0215 - val_accuracy: 0.7391 - val_loss: 2.1267
# Epoch 218/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9917 - loss: 0.0240 - val_accuracy: 0.7337 - val_loss: 2.0055
# Epoch 219/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9919 - loss: 0.0190 - val_accuracy: 0.7486 - val_loss: 2.0639
# Epoch 220/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9962 - loss: 0.0262 - val_accuracy: 0.7541 - val_loss: 2.0354
# Epoch 221/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9956 - loss: 0.0153 - val_accuracy: 0.7486 - val_loss: 2.2211
# Epoch 222/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9953 - loss: 0.0212 - val_accuracy: 0.7432 - val_loss: 2.2456
# Epoch 223/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9913 - loss: 0.0186 - val_accuracy: 0.7405 - val_loss: 1.9464
# Epoch 224/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9927 - loss: 0.0178 - val_accuracy: 0.7486 - val_loss: 1.9416
# Epoch 225/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9935 - loss: 0.0278 - val_accuracy: 0.7486 - val_loss: 2.1670
# Epoch 226/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9847 - loss: 0.0581 - val_accuracy: 0.7391 - val_loss: 2.0484
# Epoch 227/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9872 - loss: 0.0350 - val_accuracy: 0.7486 - val_loss: 1.9873
# Epoch 228/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9880 - loss: 0.0261 - val_accuracy: 0.7391 - val_loss: 2.2022
# Epoch 229/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9940 - loss: 0.0210 - val_accuracy: 0.7378 - val_loss: 2.2428
# Epoch 230/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9975 - loss: 0.0109 - val_accuracy: 0.7432 - val_loss: 2.1437
# Epoch 231/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9929 - loss: 0.0162 - val_accuracy: 0.7418 - val_loss: 2.1562
# Epoch 232/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9918 - loss: 0.0216 - val_accuracy: 0.7296 - val_loss: 2.5319
# Epoch 233/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9964 - loss: 0.0122 - val_accuracy: 0.7514 - val_loss: 2.2214
# Epoch 234/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9948 - loss: 0.0167 - val_accuracy: 0.7473 - val_loss: 2.3933
# Epoch 235/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9969 - loss: 0.0065 - val_accuracy: 0.7486 - val_loss: 2.3410
# Epoch 236/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9934 - loss: 0.0284 - val_accuracy: 0.7541 - val_loss: 2.1192
# Epoch 237/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9986 - loss: 0.0054 - val_accuracy: 0.7418 - val_loss: 2.3929
# Epoch 238/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9963 - loss: 0.0199 - val_accuracy: 0.7351 - val_loss: 2.4161
# Epoch 239/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9966 - loss: 0.0141 - val_accuracy: 0.7473 - val_loss: 2.2336
# Epoch 240/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9955 - loss: 0.0101 - val_accuracy: 0.7527 - val_loss: 2.3589
# Epoch 241/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9947 - loss: 0.0321 - val_accuracy: 0.7459 - val_loss: 2.3606
# Epoch 242/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9956 - loss: 0.0301 - val_accuracy: 0.7446 - val_loss: 2.1604
# Epoch 243/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9973 - loss: 0.0104 - val_accuracy: 0.7310 - val_loss: 2.5870
# Epoch 244/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9964 - loss: 0.0084 - val_accuracy: 0.7459 - val_loss: 2.3317
# Epoch 245/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9948 - loss: 0.0132 - val_accuracy: 0.7364 - val_loss: 2.4536
# Epoch 246/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9995 - loss: 0.0057 - val_accuracy: 0.7527 - val_loss: 2.3090
# Epoch 247/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9935 - loss: 0.0200 - val_accuracy: 0.7405 - val_loss: 2.5282
# Epoch 248/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9924 - loss: 0.0342 - val_accuracy: 0.7351 - val_loss: 2.3470
# Epoch 249/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9936 - loss: 0.0162 - val_accuracy: 0.7446 - val_loss: 2.1339
# Epoch 250/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9888 - loss: 0.0376 - val_accuracy: 0.7310 - val_loss: 2.2255
# Epoch 251/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9918 - loss: 0.0214 - val_accuracy: 0.7378 - val_loss: 2.2892
# Epoch 252/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9948 - loss: 0.0196 - val_accuracy: 0.7269 - val_loss: 2.4296
# Epoch 253/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9973 - loss: 0.0094 - val_accuracy: 0.7337 - val_loss: 2.2010
# Epoch 254/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9971 - loss: 0.0078 - val_accuracy: 0.7242 - val_loss: 2.3016
# Epoch 255/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9958 - loss: 0.0132 - val_accuracy: 0.7459 - val_loss: 2.3660
# Epoch 256/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9960 - loss: 0.0149 - val_accuracy: 0.7500 - val_loss: 2.5620
# Epoch 257/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9907 - loss: 0.0229 - val_accuracy: 0.7432 - val_loss: 2.4179
# Epoch 258/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9960 - loss: 0.0075 - val_accuracy: 0.7310 - val_loss: 2.4077
# Epoch 259/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9957 - loss: 0.0274 - val_accuracy: 0.7418 - val_loss: 2.2237
# Epoch 260/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9947 - loss: 0.0209 - val_accuracy: 0.7541 - val_loss: 2.1601
# Epoch 261/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9938 - loss: 0.0136 - val_accuracy: 0.7677 - val_loss: 2.2317
# Epoch 262/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9967 - loss: 0.0121 - val_accuracy: 0.7473 - val_loss: 2.5054
# Epoch 263/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9952 - loss: 0.0175 - val_accuracy: 0.7636 - val_loss: 2.3073
# Epoch 264/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9920 - loss: 0.0245 - val_accuracy: 0.7391 - val_loss: 2.5255
# Epoch 265/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9967 - loss: 0.0097 - val_accuracy: 0.7351 - val_loss: 2.6109
# Epoch 266/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9980 - loss: 0.0055 - val_accuracy: 0.7310 - val_loss: 2.8199
# Epoch 267/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9945 - loss: 0.0301 - val_accuracy: 0.7337 - val_loss: 2.5201
# Epoch 268/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9934 - loss: 0.0219 - val_accuracy: 0.7174 - val_loss: 2.6513
# Epoch 269/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9896 - loss: 0.0346 - val_accuracy: 0.7459 - val_loss: 2.4052
# Epoch 270/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9883 - loss: 0.0229 - val_accuracy: 0.7351 - val_loss: 2.3266
# Epoch 271/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9983 - loss: 0.0095 - val_accuracy: 0.7514 - val_loss: 2.2764
# Epoch 272/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9902 - loss: 0.0254 - val_accuracy: 0.7405 - val_loss: 2.5209
# Epoch 273/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9917 - loss: 0.0326 - val_accuracy: 0.7079 - val_loss: 2.6358
# Epoch 274/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9930 - loss: 0.0155 - val_accuracy: 0.7323 - val_loss: 2.5530
# Epoch 275/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9944 - loss: 0.0238 - val_accuracy: 0.7446 - val_loss: 2.2843
# Epoch 276/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9937 - loss: 0.0202 - val_accuracy: 0.7351 - val_loss: 2.4900
# Epoch 277/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9888 - loss: 0.0286 - val_accuracy: 0.7242 - val_loss: 2.5021
# Epoch 278/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9949 - loss: 0.0159 - val_accuracy: 0.7378 - val_loss: 2.3336
# Epoch 279/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9901 - loss: 0.0241 - val_accuracy: 0.7242 - val_loss: 2.5345
# Epoch 280/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9973 - loss: 0.0113 - val_accuracy: 0.7514 - val_loss: 2.0848
# Epoch 281/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9948 - loss: 0.0142 - val_accuracy: 0.7269 - val_loss: 2.4385
# Epoch 282/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9841 - loss: 0.0390 - val_accuracy: 0.7378 - val_loss: 2.1275
# Epoch 283/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9983 - loss: 0.0077 - val_accuracy: 0.7364 - val_loss: 2.4742
# Epoch 284/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9902 - loss: 0.0307 - val_accuracy: 0.7486 - val_loss: 2.3414
# Epoch 285/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9963 - loss: 0.0157 - val_accuracy: 0.7554 - val_loss: 2.3369
# Epoch 286/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9961 - loss: 0.0152 - val_accuracy: 0.7500 - val_loss: 2.2964
# Epoch 287/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9953 - loss: 0.0295 - val_accuracy: 0.7418 - val_loss: 2.2530
# Epoch 288/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9985 - loss: 0.0075 - val_accuracy: 0.7391 - val_loss: 2.2555
# Epoch 289/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9967 - loss: 0.0114 - val_accuracy: 0.7527 - val_loss: 2.1953
# Epoch 290/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9933 - loss: 0.0140 - val_accuracy: 0.7351 - val_loss: 2.3700
# Epoch 291/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9925 - loss: 0.0311 - val_accuracy: 0.7337 - val_loss: 2.3070
# Epoch 292/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9936 - loss: 0.0356 - val_accuracy: 0.7514 - val_loss: 2.2257
# Epoch 293/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9961 - loss: 0.0231 - val_accuracy: 0.7527 - val_loss: 2.2312
# Epoch 294/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9956 - loss: 0.0096 - val_accuracy: 0.7595 - val_loss: 2.1676
# Epoch 295/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9967 - loss: 0.0112 - val_accuracy: 0.7582 - val_loss: 2.2177
# Epoch 296/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9987 - loss: 0.0059 - val_accuracy: 0.7568 - val_loss: 2.3337
# Epoch 297/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9975 - loss: 0.0079 - val_accuracy: 0.7568 - val_loss: 2.3232
# Epoch 298/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9939 - loss: 0.0231 - val_accuracy: 0.7514 - val_loss: 2.4467
# Epoch 299/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9973 - loss: 0.0199 - val_accuracy: 0.7296 - val_loss: 2.6358
# Epoch 300/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9924 - loss: 0.0267 - val_accuracy: 0.7269 - val_loss: 2.5478
# Epoch 301/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9894 - loss: 0.0432 - val_accuracy: 0.7174 - val_loss: 2.7595
# Epoch 302/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9914 - loss: 0.0524 - val_accuracy: 0.7391 - val_loss: 2.3039
# Epoch 303/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9875 - loss: 0.0341 - val_accuracy: 0.7405 - val_loss: 2.2408
# Epoch 304/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9920 - loss: 0.0250 - val_accuracy: 0.7310 - val_loss: 2.5481
# Epoch 305/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9931 - loss: 0.0268 - val_accuracy: 0.7500 - val_loss: 2.4446
# Epoch 306/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9907 - loss: 0.0384 - val_accuracy: 0.7391 - val_loss: 2.3455
# Epoch 307/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9951 - loss: 0.0113 - val_accuracy: 0.7486 - val_loss: 2.4973
# Epoch 308/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9953 - loss: 0.0146 - val_accuracy: 0.7527 - val_loss: 2.4203
# Epoch 309/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9984 - loss: 0.0069 - val_accuracy: 0.7514 - val_loss: 2.4500
# Epoch 310/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9936 - loss: 0.0195 - val_accuracy: 0.7554 - val_loss: 2.4255
# Epoch 311/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9962 - loss: 0.0087 - val_accuracy: 0.7473 - val_loss: 2.5022
# Epoch 312/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9992 - loss: 0.0055 - val_accuracy: 0.7364 - val_loss: 2.6275
# Epoch 313/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9920 - loss: 0.0297 - val_accuracy: 0.7446 - val_loss: 2.4655
# Epoch 314/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9953 - loss: 0.0137 - val_accuracy: 0.7500 - val_loss: 2.4166
# Epoch 315/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9992 - loss: 0.0109 - val_accuracy: 0.7446 - val_loss: 2.2200
# Epoch 316/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9949 - loss: 0.0221 - val_accuracy: 0.7378 - val_loss: 2.4342
# Epoch 317/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9925 - loss: 0.0176 - val_accuracy: 0.7446 - val_loss: 2.2662
# Epoch 318/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9954 - loss: 0.0090 - val_accuracy: 0.7418 - val_loss: 2.3529
# Epoch 319/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9963 - loss: 0.0080 - val_accuracy: 0.7378 - val_loss: 2.3300
# Epoch 320/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9963 - loss: 0.0091 - val_accuracy: 0.7459 - val_loss: 2.3564
# Epoch 321/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9944 - loss: 0.0296 - val_accuracy: 0.7310 - val_loss: 2.5268
# Epoch 322/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9962 - loss: 0.0111 - val_accuracy: 0.7337 - val_loss: 2.2304
# Epoch 323/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9961 - loss: 0.0089 - val_accuracy: 0.7459 - val_loss: 2.2807
# Epoch 324/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9994 - loss: 0.0041 - val_accuracy: 0.7473 - val_loss: 2.2908
# Epoch 325/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9970 - loss: 0.0152 - val_accuracy: 0.7228 - val_loss: 2.4501
# Epoch 326/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9920 - loss: 0.0171 - val_accuracy: 0.7432 - val_loss: 2.5036
# Epoch 327/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9938 - loss: 0.0145 - val_accuracy: 0.7378 - val_loss: 2.3762
# Epoch 328/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9934 - loss: 0.0121 - val_accuracy: 0.7418 - val_loss: 2.4727
# Epoch 329/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9972 - loss: 0.0102 - val_accuracy: 0.7446 - val_loss: 2.4650
# Epoch 330/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9941 - loss: 0.0095 - val_accuracy: 0.7486 - val_loss: 2.6656
# Epoch 331/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9962 - loss: 0.0096 - val_accuracy: 0.7255 - val_loss: 2.5982
# Epoch 332/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9954 - loss: 0.0162 - val_accuracy: 0.7351 - val_loss: 2.5480
# Epoch 333/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9988 - loss: 0.0064 - val_accuracy: 0.7405 - val_loss: 2.5564
# Epoch 334/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9983 - loss: 0.0079 - val_accuracy: 0.7554 - val_loss: 2.4179
# Epoch 335/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9985 - loss: 0.0080 - val_accuracy: 0.7568 - val_loss: 2.4470
# Epoch 336/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9964 - loss: 0.0092 - val_accuracy: 0.7527 - val_loss: 2.4787
# Epoch 337/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9968 - loss: 0.0209 - val_accuracy: 0.7378 - val_loss: 2.6551
# Epoch 338/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9915 - loss: 0.0234 - val_accuracy: 0.7310 - val_loss: 2.6963
# Epoch 339/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9994 - loss: 0.0036 - val_accuracy: 0.7418 - val_loss: 2.6498
# Epoch 340/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9999 - loss: 0.0021 - val_accuracy: 0.7391 - val_loss: 2.7191
# Epoch 341/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9973 - loss: 0.0100 - val_accuracy: 0.7446 - val_loss: 2.6070
# Epoch 342/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9997 - loss: 0.0049 - val_accuracy: 0.7473 - val_loss: 2.5584
# Epoch 343/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9969 - loss: 0.0081 - val_accuracy: 0.7296 - val_loss: 2.8614
# Epoch 344/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9981 - loss: 0.0058 - val_accuracy: 0.7473 - val_loss: 2.7269
# Epoch 345/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9981 - loss: 0.0046 - val_accuracy: 0.7242 - val_loss: 2.9792
# Epoch 346/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9975 - loss: 0.0138 - val_accuracy: 0.7188 - val_loss: 2.9420
# Epoch 347/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9949 - loss: 0.0191 - val_accuracy: 0.7337 - val_loss: 2.6949
# Epoch 348/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9919 - loss: 0.0323 - val_accuracy: 0.7459 - val_loss: 2.6057
# Epoch 349/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9989 - loss: 0.0121 - val_accuracy: 0.7541 - val_loss: 2.6602
# Epoch 350/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9938 - loss: 0.0159 - val_accuracy: 0.7351 - val_loss: 2.4976
# Epoch 351/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9951 - loss: 0.0206 - val_accuracy: 0.7378 - val_loss: 2.6137
# Epoch 352/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9988 - loss: 0.0052 - val_accuracy: 0.7269 - val_loss: 2.9501
# Epoch 353/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9930 - loss: 0.0118 - val_accuracy: 0.7364 - val_loss: 3.0003
# Epoch 354/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9967 - loss: 0.0071 - val_accuracy: 0.7418 - val_loss: 2.7671
# Epoch 355/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9959 - loss: 0.0065 - val_accuracy: 0.7486 - val_loss: 2.8336
# Epoch 356/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9989 - loss: 0.0072 - val_accuracy: 0.7432 - val_loss: 2.6503
# Epoch 357/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9975 - loss: 0.0125 - val_accuracy: 0.7514 - val_loss: 2.8183
# Epoch 358/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9984 - loss: 0.0038 - val_accuracy: 0.7514 - val_loss: 2.7943
# Epoch 359/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9967 - loss: 0.0078 - val_accuracy: 0.7541 - val_loss: 2.6919
# Epoch 360/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9987 - loss: 0.0040 - val_accuracy: 0.7554 - val_loss: 2.8286
# Epoch 361/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9952 - loss: 0.0246 - val_accuracy: 0.7228 - val_loss: 3.3364
# Epoch 362/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9923 - loss: 0.0264 - val_accuracy: 0.7283 - val_loss: 3.3244
# Epoch 363/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9840 - loss: 0.0535 - val_accuracy: 0.7242 - val_loss: 3.2299
# Epoch 364/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9935 - loss: 0.0233 - val_accuracy: 0.7323 - val_loss: 2.9572
# Epoch 365/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9971 - loss: 0.0118 - val_accuracy: 0.7446 - val_loss: 2.9019
# Epoch 366/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9894 - loss: 0.0240 - val_accuracy: 0.7541 - val_loss: 2.7637
# Epoch 367/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9962 - loss: 0.0193 - val_accuracy: 0.7283 - val_loss: 2.9233
# Epoch 368/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9956 - loss: 0.0177 - val_accuracy: 0.7364 - val_loss: 2.7836
# Epoch 369/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9960 - loss: 0.0121 - val_accuracy: 0.7283 - val_loss: 2.9918
# Epoch 370/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9927 - loss: 0.0308 - val_accuracy: 0.7283 - val_loss: 2.8715
# ...
# Epoch 378/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9964 - loss: 0.0109 - val_accuracy: 0.7405 - val_loss: 3.0045
# Epoch 379/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9972 - loss: 0.0095 - val_accuracy: 0.7595 - val_loss: 2.7690
# Epoch 380/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9952 - loss: 0.0092 - val_accuracy: 0.7541 - val_loss: 2.8521
# Epoch 381/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9937 - loss: 0.0222 - val_accuracy: 0.7405 - val_loss: 2.8368
# Epoch 382/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9939 - loss: 0.0120 - val_accuracy: 0.7283 - val_loss: 3.0175
# Epoch 383/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9972 - loss: 0.0083 - val_accuracy: 0.7255 - val_loss: 2.8888
# Epoch 384/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9951 - loss: 0.0082 - val_accuracy: 0.7473 - val_loss: 3.0176
# Epoch 385/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9979 - loss: 0.0053 - val_accuracy: 0.7432 - val_loss: 3.3303
# Epoch 386/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9921 - loss: 0.0098 - val_accuracy: 0.7405 - val_loss: 3.2061
# Epoch 387/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9971 - loss: 0.0073 - val_accuracy: 0.7378 - val_loss: 3.0482
# Epoch 388/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9988 - loss: 0.0142 - val_accuracy: 0.7459 - val_loss: 3.0459
# Epoch 389/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9973 - loss: 0.0064 - val_accuracy: 0.7473 - val_loss: 2.9086
# Epoch 390/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9969 - loss: 0.0080 - val_accuracy: 0.7527 - val_loss: 2.8309
# Epoch 391/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9884 - loss: 0.0276 - val_accuracy: 0.7582 - val_loss: 2.8729
# Epoch 392/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9877 - loss: 0.0333 - val_accuracy: 0.7418 - val_loss: 3.0087
# Epoch 393/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9933 - loss: 0.0229 - val_accuracy: 0.7582 - val_loss: 2.7728
# Epoch 394/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9976 - loss: 0.0109 - val_accuracy: 0.7418 - val_loss: 2.8041
# Epoch 395/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9932 - loss: 0.0209 - val_accuracy: 0.7622 - val_loss: 2.6088
# Epoch 396/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9938 - loss: 0.0144 - val_accuracy: 0.7446 - val_loss: 2.9451
# Epoch 397/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9973 - loss: 0.0121 - val_accuracy: 0.7337 - val_loss: 3.2907
# Epoch 398/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9909 - loss: 0.0329 - val_accuracy: 0.7446 - val_loss: 3.0343
# Epoch 399/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9984 - loss: 0.0199 - val_accuracy: 0.7269 - val_loss: 3.2334
# Epoch 400/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9954 - loss: 0.0168 - val_accuracy: 0.7500 - val_loss: 2.7588
# Epoch 401/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9984 - loss: 0.0054 - val_accuracy: 0.7473 - val_loss: 2.6716
# Epoch 402/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9989 - loss: 0.0054 - val_accuracy: 0.7595 - val_loss: 2.5900
# Epoch 403/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9981 - loss: 0.0074 - val_accuracy: 0.7527 - val_loss: 2.7487
# Epoch 404/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9971 - loss: 0.0065 - val_accuracy: 0.7459 - val_loss: 2.9198
# Epoch 405/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9996 - loss: 0.0020 - val_accuracy: 0.7418 - val_loss: 2.9327
# Epoch 406/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9977 - loss: 0.0050 - val_accuracy: 0.7391 - val_loss: 3.0526
# Epoch 407/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9966 - loss: 0.0093 - val_accuracy: 0.7391 - val_loss: 3.0291
# Epoch 408/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9966 - loss: 0.0093 - val_accuracy: 0.7459 - val_loss: 3.0223
# Epoch 409/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9961 - loss: 0.0120 - val_accuracy: 0.7446 - val_loss: 2.9749
# Epoch 410/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9974 - loss: 0.0065 - val_accuracy: 0.7568 - val_loss: 2.8163
# Epoch 411/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9921 - loss: 0.0191 - val_accuracy: 0.7459 - val_loss: 2.9084
# Epoch 412/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9978 - loss: 0.0089 - val_accuracy: 0.7391 - val_loss: 3.1795
# Epoch 413/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9955 - loss: 0.0141 - val_accuracy: 0.7215 - val_loss: 3.6592
# Epoch 414/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9906 - loss: 0.0429 - val_accuracy: 0.7364 - val_loss: 3.1126
# Epoch 415/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9972 - loss: 0.0115 - val_accuracy: 0.7432 - val_loss: 2.8790
# Epoch 416/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9973 - loss: 0.0091 - val_accuracy: 0.7310 - val_loss: 3.0270
# Epoch 417/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9991 - loss: 0.0040 - val_accuracy: 0.7351 - val_loss: 3.3063
# Epoch 418/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9958 - loss: 0.0175 - val_accuracy: 0.7473 - val_loss: 2.9153
# Epoch 419/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9967 - loss: 0.0117 - val_accuracy: 0.7473 - val_loss: 2.9586
# Epoch 420/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9911 - loss: 0.0407 - val_accuracy: 0.7432 - val_loss: 2.8235
# Epoch 421/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9963 - loss: 0.0202 - val_accuracy: 0.7459 - val_loss: 2.6457
# Epoch 422/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9959 - loss: 0.0156 - val_accuracy: 0.7446 - val_loss: 2.6607
# Epoch 423/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9985 - loss: 0.0072 - val_accuracy: 0.7418 - val_loss: 2.7914
# Epoch 424/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9973 - loss: 0.0064 - val_accuracy: 0.7500 - val_loss: 3.0627
# Epoch 425/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9987 - loss: 0.0092 - val_accuracy: 0.7378 - val_loss: 3.1129
# Epoch 426/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9990 - loss: 0.0044 - val_accuracy: 0.7405 - val_loss: 2.9745
# Epoch 427/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9957 - loss: 0.0119 - val_accuracy: 0.7446 - val_loss: 3.2068
# Epoch 428/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9945 - loss: 0.0130 - val_accuracy: 0.7405 - val_loss: 2.8985
# Epoch 429/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9958 - loss: 0.0062 - val_accuracy: 0.7446 - val_loss: 3.1197
# Epoch 430/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9919 - loss: 0.0187 - val_accuracy: 0.7418 - val_loss: 2.9096
# Epoch 431/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9968 - loss: 0.0226 - val_accuracy: 0.7514 - val_loss: 3.0248
# Epoch 432/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9963 - loss: 0.0078 - val_accuracy: 0.7500 - val_loss: 2.9325
# Epoch 433/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9974 - loss: 0.0136 - val_accuracy: 0.7541 - val_loss: 2.7101
# Epoch 434/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9971 - loss: 0.0132 - val_accuracy: 0.7228 - val_loss: 2.8865
# Epoch 435/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9966 - loss: 0.0145 - val_accuracy: 0.7418 - val_loss: 2.4919
# Epoch 436/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9971 - loss: 0.0161 - val_accuracy: 0.7486 - val_loss: 2.4503
# Epoch 437/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9969 - loss: 0.0062 - val_accuracy: 0.7473 - val_loss: 2.5514
# Epoch 438/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9986 - loss: 0.0069 - val_accuracy: 0.7391 - val_loss: 2.6727
# Epoch 439/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9960 - loss: 0.0093 - val_accuracy: 0.7473 - val_loss: 2.9935
# Epoch 440/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9963 - loss: 0.0120 - val_accuracy: 0.7391 - val_loss: 3.1178
# Epoch 441/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9957 - loss: 0.0279 - val_accuracy: 0.7364 - val_loss: 2.9782
# Epoch 442/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9979 - loss: 0.0072 - val_accuracy: 0.7459 - val_loss: 2.7540
# Epoch 443/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9968 - loss: 0.0060 - val_accuracy: 0.7446 - val_loss: 2.8049
# Epoch 444/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9987 - loss: 0.0051 - val_accuracy: 0.7486 - val_loss: 2.9457
# Epoch 445/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9961 - loss: 0.0128 - val_accuracy: 0.7473 - val_loss: 2.8078
# Epoch 446/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9994 - loss: 0.0049 - val_accuracy: 0.7337 - val_loss: 2.9103
# Epoch 447/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9952 - loss: 0.0115 - val_accuracy: 0.7310 - val_loss: 2.9188
# Epoch 448/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9988 - loss: 0.0063 - val_accuracy: 0.7459 - val_loss: 2.9559
# Epoch 449/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9954 - loss: 0.0093 - val_accuracy: 0.7418 - val_loss: 2.7839
# Epoch 450/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9990 - loss: 0.0029 - val_accuracy: 0.7527 - val_loss: 2.7811
# Epoch 451/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9937 - loss: 0.0168 - val_accuracy: 0.7378 - val_loss: 3.1116
# Epoch 452/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9966 - loss: 0.0136 - val_accuracy: 0.7337 - val_loss: 3.2417
# Epoch 453/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9908 - loss: 0.0302 - val_accuracy: 0.7541 - val_loss: 2.9901
# Epoch 454/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9940 - loss: 0.0234 - val_accuracy: 0.7310 - val_loss: 3.1816
# Epoch 455/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9983 - loss: 0.0232 - val_accuracy: 0.7473 - val_loss: 2.9198
# Epoch 456/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9963 - loss: 0.0104 - val_accuracy: 0.7201 - val_loss: 3.3749
# Epoch 457/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9960 - loss: 0.0190 - val_accuracy: 0.7405 - val_loss: 3.3330
# Epoch 458/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9984 - loss: 0.0128 - val_accuracy: 0.7582 - val_loss: 2.9336
# Epoch 459/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9970 - loss: 0.0090 - val_accuracy: 0.7649 - val_loss: 2.7590
# Epoch 460/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9991 - loss: 0.0033 - val_accuracy: 0.7527 - val_loss: 2.8061
# Epoch 461/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9999 - loss: 0.0053 - val_accuracy: 0.7527 - val_loss: 3.2122
# Epoch 462/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9920 - loss: 0.0204 - val_accuracy: 0.7527 - val_loss: 2.8549
# Epoch 463/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9966 - loss: 0.0093 - val_accuracy: 0.7568 - val_loss: 2.9502
# Epoch 464/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9991 - loss: 0.0021 - val_accuracy: 0.7554 - val_loss: 3.1071
# Epoch 465/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9981 - loss: 0.0078 - val_accuracy: 0.7514 - val_loss: 3.4142
# Epoch 466/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9992 - loss: 0.0043 - val_accuracy: 0.7582 - val_loss: 2.9189
# Epoch 467/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9971 - loss: 0.0078 - val_accuracy: 0.7568 - val_loss: 2.9885
# Epoch 468/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9970 - loss: 0.0389 - val_accuracy: 0.7527 - val_loss: 2.7882
# Epoch 469/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9958 - loss: 0.0097 - val_accuracy: 0.7636 - val_loss: 2.9034
# Epoch 470/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9943 - loss: 0.0087 - val_accuracy: 0.7418 - val_loss: 3.1454
# Epoch 471/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9940 - loss: 0.0244 - val_accuracy: 0.7418 - val_loss: 3.2317
# Epoch 472/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9965 - loss: 0.0090 - val_accuracy: 0.7459 - val_loss: 3.1543
# Epoch 473/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9954 - loss: 0.0107 - val_accuracy: 0.7432 - val_loss: 3.2961
# Epoch 474/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9959 - loss: 0.0148 - val_accuracy: 0.7568 - val_loss: 3.2567
# Epoch 475/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9949 - loss: 0.0109 - val_accuracy: 0.7609 - val_loss: 3.2000
# Epoch 476/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9972 - loss: 0.0080 - val_accuracy: 0.7527 - val_loss: 3.4947
# Epoch 477/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9962 - loss: 0.0065 - val_accuracy: 0.7473 - val_loss: 3.4515
# Epoch 478/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9964 - loss: 0.0121 - val_accuracy: 0.7622 - val_loss: 3.0582
# Epoch 479/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9954 - loss: 0.0186 - val_accuracy: 0.7473 - val_loss: 3.1715
# Epoch 480/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9963 - loss: 0.0484 - val_accuracy: 0.7609 - val_loss: 2.9494
# Epoch 481/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9957 - loss: 0.0179 - val_accuracy: 0.7568 - val_loss: 3.0847
# Epoch 482/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9978 - loss: 0.0093 - val_accuracy: 0.7446 - val_loss: 3.1501
# Epoch 483/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9977 - loss: 0.0050 - val_accuracy: 0.7582 - val_loss: 3.0465
# Epoch 484/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9976 - loss: 0.0050 - val_accuracy: 0.7418 - val_loss: 3.2826
# Epoch 485/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9943 - loss: 0.0432 - val_accuracy: 0.7527 - val_loss: 2.9802
# Epoch 486/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9931 - loss: 0.0113 - val_accuracy: 0.7459 - val_loss: 2.9792
# Epoch 487/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9969 - loss: 0.0077 - val_accuracy: 0.7337 - val_loss: 3.1512
# Epoch 488/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9966 - loss: 0.0093 - val_accuracy: 0.7351 - val_loss: 3.1263
# Epoch 489/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9951 - loss: 0.0214 - val_accuracy: 0.7296 - val_loss: 2.9875
# Epoch 490/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9919 - loss: 0.0253 - val_accuracy: 0.7486 - val_loss: 3.0033
# Epoch 491/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9927 - loss: 0.0220 - val_accuracy: 0.7500 - val_loss: 3.1157
# Epoch 492/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9941 - loss: 0.0164 - val_accuracy: 0.7446 - val_loss: 3.2243
# Epoch 493/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9974 - loss: 0.0087 - val_accuracy: 0.7446 - val_loss: 3.1223
# Epoch 494/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9973 - loss: 0.0077 - val_accuracy: 0.7378 - val_loss: 3.1412
# Epoch 495/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9964 - loss: 0.0132 - val_accuracy: 0.7527 - val_loss: 2.8878
# Epoch 496/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9959 - loss: 0.0098 - val_accuracy: 0.7527 - val_loss: 2.7556
# Epoch 497/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9982 - loss: 0.0076 - val_accuracy: 0.7486 - val_loss: 3.0023
# Epoch 498/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9962 - loss: 0.0120 - val_accuracy: 0.7473 - val_loss: 3.1006
# Epoch 499/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9953 - loss: 0.0128 - val_accuracy: 0.7459 - val_loss: 3.1313
# Epoch 500/500
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9976 - loss: 0.0074 - val_accuracy: 0.7554 - val_loss: 3.1414

# %%
# Save Model
model.save(r"I:\My Drive\SpeechEmotionDetection\models\speech_emotion_model.h5")
print("Model trained and saved!")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model trained and saved!

# %% [markdown]
# ### Model Evaluation 📊
# - Model evaluation is the process of assessing how well a trained model performs on unseen data. It helps determine accuracy, robustness, and generalization before deployment.
# - Once the model is trained, we evaluate its performance using various metrics:
#     1. **Accuracy** - Measures overall correctness.
#     2. **Precision & Recall** - Important for imbalanced datasets.
#     3. **F1-Score** - Balances precision and recall.
#     4. **Confusion Matrix** - Provides a detailed view of model errors.
#     5. **Loss Function** - Determines model optimization.
#
# We will use **Scikit-learn** to compute these metrics and visualize performance.

# %%
# Reshape input
X_test = np.expand_dims(X_test, axis=2)

# %%
# Load Saved model
model = tf_models.load_model("I:\My Drive\SpeechEmotionDetection\models\speech_emotion_model.h5")
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\M'
# <>:2: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\EL-Dorado\AppData\Local\Temp\ipykernel_2668\2980199587.py:2: SyntaxWarning: invalid escape sequence '\M'
#   model = tf_models.load_model("I:\My Drive\SpeechEmotionDetection\models\speech_emotion_model.h5")
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
# Predict Output
y_pred = np.argmax(model.predict(X_test), axis=1)
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
# Evaluate Print
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.77      0.82       116
#            1       0.74      0.90      0.81       102
#            2       0.73      0.70      0.72        54
#            3       0.70      0.76      0.73       105
#            4       0.81      0.68      0.74       125
#            5       0.72      0.79      0.75        56
#            6       0.71      0.74      0.72       119
#            7       0.75      0.68      0.71        59
#
#     accuracy                           0.76       736
#    macro avg       0.75      0.75      0.75       736
# weighted avg       0.76      0.76      0.75       736

# %% [markdown]
# ### Confusion Matrix Visualization 🎯
# A **confusion matrix** is a useful tool to evaluate the performance of a classification model. It shows:
# - **Correct classifications** along the diagonal.
# - **Misclassifications** off the diagonal.
#
# We use **Seaborn’s heatmap** to visually analyze model errors and performance.

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=label_encoder.classes_,
            yticklabels=label_encoder.classes_)
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix")
plt.show()

# %%
# Extract loss values
train_loss = history.history['loss']
val_loss = history.history['val_loss']

# Plot training & validation loss values
plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training vs Validation Loss')
plt.legend()
plt.show()
